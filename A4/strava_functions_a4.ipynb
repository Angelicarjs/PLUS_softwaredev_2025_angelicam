# %% [markdown]
# ## Strava Data Exploration
#
# This notebook uses a Python module `strava_analysis.py` to analyze and visualize activity data exported from Strava.

# %%
import strava_analysis
dir(strava_analysis)
# Out:
# ['Point',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'extract_lat_lon',
#  'folium',
#  'gpd',
#  'load_strava_data',
#  'map_df',
#  'pd',
#  'plot_speed_distribution',
#  'plt',
#  'sns']

# %%
# Import your functions
from strava_analysis import load_strava_data, plot_speed_distribution, extract_lat_lon, map_df

# %% [markdown]
# ### 1. Load the data
# We use a function `load_strava_data()` that selects relevant columns, parses dates, and removes incomplete rows.

# %%
#Use first function, upload the data
df = load_strava_data("strava_data.csv")
df
# Out:
#                              name    upload_id     type  distance  \
# 0                  Afternoon HIIT  15470552955  Workout       0.0
# 1                    Evening HIIT  15460331668  Workout       0.0
# 2    Lunch Ride - Innersbachklamm  15449061470     Ride  102228.0
# 3                   Night Workout  15439339287  Workout       0.0
# 4               Afternoon Workout  15426341743  Workout       0.0
# ..                            ...          ...      ...       ...
# 215                  Morning Ride   9917797597     Ride   10296.7
# 216                    Lunch Walk   9255579410     Walk    3998.6
# 217                   Arbolito 🌲    8952619873     Ride   23473.4
# 218       Ricaurte - Agua de Dios   8948754056     Ride   44084.1
# 219                  Morning Walk   8602123097     Walk    3670.9
#
#      moving_time  average_speed  max_speed  total_elevation_gain  \
# 0           4531          0.000      0.000                   0.0
# 1           3774          0.000      0.000                   0.0
# 2          21805          4.688     18.043                 545.7
# 3           4233          0.000      0.000                   0.0
# 4           7148          0.000      0.000                   0.0
# ..           ...            ...        ...                   ...
# 215         3654          2.818      7.982                 344.1
# 216         3009          1.329      1.909                   7.7
# 217         7171          3.273     10.387                 452.4
# 218         6479          6.804     15.073                 375.5
# 219         2952          1.244      2.703                  18.3
#
#     start_date_local                             start_latlng  \
# 0         2025-05-16                                       []
# 1         2025-05-15                                       []
# 2         2025-05-14                   [47.810196, 13.038183]
# 3         2025-05-13                                       []
# 4         2025-05-12                                       []
# ..               ...                                      ...
# 215       2023-06-10  [4.297962170094252, -74.78609061799943]
# 216       2023-02-25                    [4.75921, -74.066105]
# 217       2023-01-06                   [4.297663, -74.784424]
# 218       2023-01-05                   [4.295948, -74.786636]
# 219       2022-10-29                   [4.749332, -74.089201]
#
#                                   end_latlng  \
# 0                                         []
# 1                                         []
# 2                     [47.810232, 13.038135]
# 3                                         []
# 4                                         []
# ..                                       ...
# 215  [4.348327768966556, -74.83286884613335]
# 216                   [4.724326, -74.073518]
# 217                   [4.297661, -74.784449]
# 218                    [4.297545, -74.78435]
# 219                   [4.749291, -74.089532]
#
#                                   map.summary_polyline start_time
# 0                                                  NaN   17:44:26
# 1                                                  NaN   18:24:27
# 2    oaybHkcqnAvMdFfBnr@{CZrCh@LbIqE`X~OpMaHzGqPnz@...   11:02:05
# 3                                                  NaN   20:38:54
# 4                                                  NaN   17:59:28
# ..                                                 ...        ...
# 215  }ffYlumgMtCh@`@JzBb@l@^FF?NAJW~A{@nEQn@]t@aAbB...   07:35:28
# 216  mf`\f~`cMtCc@rE_@b@AZEFBP?REJCfAITIt@Aj@GdBGdB...   12:39:16
# 217  egfYjumgMhI|Af@XAj@oAtG{@fCqBzCcAj@qFhBoQhNy@f...   06:39:16
# 218  c{eYrwmgMV_@v@wDdBwFdH_RtHeL|RqPkTuIsFeBuQiHgK...   16:17:54
# 219  ir~[ppecM@OKISKa@[QIIA]Yq@]I@IHS\UVCVFZ\n@VVDJ...   10:02:58
#
# [220 rows x 13 columns]

# %% [markdown]
# ### 2. Visualize Speed
# The function `plot_speed_distribution()` compares the average and max speeds using histograms.

# %%
# plot speed distribution
plot_speed_distribution(df)

# %%
df
# Out:
#                              name    upload_id     type  distance  \
# 0                  Afternoon HIIT  15470552955  Workout       0.0
# 1                    Evening HIIT  15460331668  Workout       0.0
# 2    Lunch Ride - Innersbachklamm  15449061470     Ride  102228.0
# 3                   Night Workout  15439339287  Workout       0.0
# 4               Afternoon Workout  15426341743  Workout       0.0
# ..                            ...          ...      ...       ...
# 215                  Morning Ride   9917797597     Ride   10296.7
# 216                    Lunch Walk   9255579410     Walk    3998.6
# 217                   Arbolito 🌲    8952619873     Ride   23473.4
# 218       Ricaurte - Agua de Dios   8948754056     Ride   44084.1
# 219                  Morning Walk   8602123097     Walk    3670.9
#
#      moving_time  average_speed  max_speed  total_elevation_gain  \
# 0           4531          0.000      0.000                   0.0
# 1           3774          0.000      0.000                   0.0
# 2          21805          4.688     18.043                 545.7
# 3           4233          0.000      0.000                   0.0
# 4           7148          0.000      0.000                   0.0
# ..           ...            ...        ...                   ...
# 215         3654          2.818      7.982                 344.1
# 216         3009          1.329      1.909                   7.7
# 217         7171          3.273     10.387                 452.4
# 218         6479          6.804     15.073                 375.5
# 219         2952          1.244      2.703                  18.3
#
#     start_date_local                             start_latlng  \
# 0         2025-05-16                                       []
# 1         2025-05-15                                       []
# 2         2025-05-14                   [47.810196, 13.038183]
# 3         2025-05-13                                       []
# 4         2025-05-12                                       []
# ..               ...                                      ...
# 215       2023-06-10  [4.297962170094252, -74.78609061799943]
# 216       2023-02-25                    [4.75921, -74.066105]
# 217       2023-01-06                   [4.297663, -74.784424]
# 218       2023-01-05                   [4.295948, -74.786636]
# 219       2022-10-29                   [4.749332, -74.089201]
#
#                                   end_latlng  \
# 0                                         []
# 1                                         []
# 2                     [47.810232, 13.038135]
# 3                                         []
# 4                                         []
# ..                                       ...
# 215  [4.348327768966556, -74.83286884613335]
# 216                   [4.724326, -74.073518]
# 217                   [4.297661, -74.784449]
# 218                    [4.297545, -74.78435]
# 219                   [4.749291, -74.089532]
#
#                                   map.summary_polyline start_time
# 0                                                  NaN   17:44:26
# 1                                                  NaN   18:24:27
# 2    oaybHkcqnAvMdFfBnr@{CZrCh@LbIqE`X~OpMaHzGqPnz@...   11:02:05
# 3                                                  NaN   20:38:54
# 4                                                  NaN   17:59:28
# ..                                                 ...        ...
# 215  }ffYlumgMtCh@`@JzBb@l@^FF?NAJW~A{@nEQn@]t@aAbB...   07:35:28
# 216  mf`\f~`cMtCc@rE_@b@AZEFBP?REJCfAITIt@Aj@GdBGdB...   12:39:16
# 217  egfYjumgMhI|Af@XAj@oAtG{@fCqBzCcAj@qFhBoQhNy@f...   06:39:16
# 218  c{eYrwmgMV_@v@wDdBwFdH_RtHeL|RqPkTuIsFeBuQiHgK...   16:17:54
# 219  ir~[ppecM@OKISKa@[QIIA]Yq@]I@IHS\UVCVFZ\n@VVDJ...   10:02:58
#
# [220 rows x 13 columns]

# %% [markdown]
# ### 3.  Extract latitude and longitude
#
# With `extract_lat_lon()`, we extract in two columns for each couple of coordenates separated information.

# %%
df['start_lat'], df['start_lon'] = zip(*df['start_latlng'].map(extract_lat_lon))
df['end_lat'], df['end_lon'] = zip(*df['end_latlng'].map(extract_lat_lon))
df
# Out:
#                              name    upload_id     type  distance  \
# 0                  Afternoon HIIT  15470552955  Workout       0.0
# 1                    Evening HIIT  15460331668  Workout       0.0
# 2    Lunch Ride - Innersbachklamm  15449061470     Ride  102228.0
# 3                   Night Workout  15439339287  Workout       0.0
# 4               Afternoon Workout  15426341743  Workout       0.0
# ..                            ...          ...      ...       ...
# 215                  Morning Ride   9917797597     Ride   10296.7
# 216                    Lunch Walk   9255579410     Walk    3998.6
# 217                   Arbolito 🌲    8952619873     Ride   23473.4
# 218       Ricaurte - Agua de Dios   8948754056     Ride   44084.1
# 219                  Morning Walk   8602123097     Walk    3670.9
#
#      moving_time  average_speed  max_speed  total_elevation_gain  \
# 0           4531          0.000      0.000                   0.0
# 1           3774          0.000      0.000                   0.0
# 2          21805          4.688     18.043                 545.7
# 3           4233          0.000      0.000                   0.0
# 4           7148          0.000      0.000                   0.0
# ..           ...            ...        ...                   ...
# 215         3654          2.818      7.982                 344.1
# 216         3009          1.329      1.909                   7.7
# 217         7171          3.273     10.387                 452.4
# 218         6479          6.804     15.073                 375.5
# 219         2952          1.244      2.703                  18.3
#
#     start_date_local                             start_latlng  \
# 0         2025-05-16                                       []
# 1         2025-05-15                                       []
# 2         2025-05-14                   [47.810196, 13.038183]
# 3         2025-05-13                                       []
# 4         2025-05-12                                       []
# ..               ...                                      ...
# 215       2023-06-10  [4.297962170094252, -74.78609061799943]
# 216       2023-02-25                    [4.75921, -74.066105]
# 217       2023-01-06                   [4.297663, -74.784424]
# 218       2023-01-05                   [4.295948, -74.786636]
# 219       2022-10-29                   [4.749332, -74.089201]
#
#                                   end_latlng  \
# 0                                         []
# 1                                         []
# 2                     [47.810232, 13.038135]
# 3                                         []
# 4                                         []
# ..                                       ...
# 215  [4.348327768966556, -74.83286884613335]
# 216                   [4.724326, -74.073518]
# 217                   [4.297661, -74.784449]
# 218                    [4.297545, -74.78435]
# 219                   [4.749291, -74.089532]
#
#                                   map.summary_polyline start_time  start_lat  \
# 0                                                  NaN   17:44:26        NaN
# 1                                                  NaN   18:24:27        NaN
# 2    oaybHkcqnAvMdFfBnr@{CZrCh@LbIqE`X~OpMaHzGqPnz@...   11:02:05  47.810196
# 3                                                  NaN   20:38:54        NaN
# 4                                                  NaN   17:59:28        NaN
# ..                                                 ...        ...        ...
# 215  }ffYlumgMtCh@`@JzBb@l@^FF?NAJW~A{@nEQn@]t@aAbB...   07:35:28   4.297962
# 216  mf`\f~`cMtCc@rE_@b@AZEFBP?REJCfAITIt@Aj@GdBGdB...   12:39:16   4.759210
# 217  egfYjumgMhI|Af@XAj@oAtG{@fCqBzCcAj@qFhBoQhNy@f...   06:39:16   4.297663
# 218  c{eYrwmgMV_@v@wDdBwFdH_RtHeL|RqPkTuIsFeBuQiHgK...   16:17:54   4.295948
# 219  ir~[ppecM@OKISKa@[QIIA]Yq@]I@IHS\UVCVFZ\n@VVDJ...   10:02:58   4.749332
#
#      start_lon    end_lat    end_lon
# 0          NaN        NaN        NaN
# 1          NaN        NaN        NaN
# 2    13.038183  47.810232  13.038135
# 3          NaN        NaN        NaN
# 4          NaN        NaN        NaN
# ..         ...        ...        ...
# 215 -74.786091   4.348328 -74.832869
# 216 -74.066105   4.724326 -74.073518
# 217 -74.784424   4.297661 -74.784449
# 218 -74.786636   4.297545 -74.784350
# 219 -74.089201   4.749291 -74.089532
#
# [220 rows x 17 columns]

# %% [markdown]
# ### 4. Map the Activity Starts
# With `map_df()`, we visualize where each activity began using folium.

# %%
#Show activity start points
fmap = map_df(df)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9834888850ce3962c051ef76e4f4789 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9834888850ce3962c051ef76e4f4789&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9834888850ce3962c051ef76e4f4789 = L.map(
#                 &quot;map_c9834888850ce3962c051ef76e4f4789&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd350aff493cff5c4db0919ae85d5671 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd350aff493cff5c4db0919ae85d5671.addTo(map_c9834888850ce3962c051ef76e4f4789);
#
#
#             var circle_marker_46d40be648cecc41e9d1f01335542ea6 = L.circleMarker(
#                 [47.810196, 13.038183],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c9834888850ce3962c051ef76e4f4789);
#
#
#         var popup_4c9ed6b45d0971007bbd1ca889f56ee9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7de6d41b4362948ad7dc9f11bda3e638 = $(`&lt;div id=&quot;html_7de6d41b4362948ad7dc9f11bda3e638&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lunch Ride - Innersbachklamm (Ride) - Start&lt;/div&gt;`)[0];
#                 popup_4c9ed6b45d0971007bbd1ca889f56ee9.setContent(html_7de6d41b4362948ad7dc9f11bda3e638);
#
#
#
#         circle_marker_46d40be648cecc41e9d1f01335542ea6.bindPopup(popup_4c9ed6b45d0971007bbd1ca889f56ee9)
#         ;
#
#
#
#
#             var circle_marker_09955b07b03e8de96ec63d995a786181 = L.circleMarker(
#                 [47.810012, 13.037966],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c9834888850ce3962c051ef76e4f4789);
#
#
#         var popup_5ff4673db4be31c5638450e21b2dcc16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1147a956d7926a0f1dbdff9167e98be4 = $(`&lt;div id=&quot;html_1147a956d7926a0f1dbdff9167e98be4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Afternoon Ride (Ride) - Start&lt;/div&gt;`)[0];
#                 popup_5ff4673db4be31c5638450e21b2dcc16.setContent(html_1147a956d7926a0f1dbdff9167e98be4);
#
#
#
#         circle_marker_09955b07b03e8de96ec63d995a786181.bindPopup(popup_5ff4673db4be31c5638450e21b2dcc16)
#         ;
#
#
#
#
#             var circle_marker_7f16a247b1e32cf38fddf2097994b81d = L.circleMarker(
#                 [47.810077, 13.037723],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c9834888850ce3962c051ef76e4f4789);
#
#
#         var popup_68bbcc48364ba209b5ab57fe6976dfbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef514e182b7a9b54ae5311211212163c = $(`&lt;div id=&quot;html_ef514e182b7a9b54ae5311211212163c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lunch Ride - Wiestaltausee (Ride) - Start&lt;/div&gt;`)[0];
#                 popup_68bbcc48364ba209b5ab57fe6976dfbd.setContent(html_ef514e182b7a9b54ae5311211212163c);
#
#
#
#         circle_marker_7f16a247b1e32cf38fddf2097994b81d.bindPopup(popup_68bbcc48364ba209b5ab57fe6976dfbd)
#         ;
#
#
#
#
#             var
